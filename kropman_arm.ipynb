# %%
import pandas as pd
import string
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import word_tokenize
from mlxtend.preprocessing import TransactionEncoder
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kouro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kouro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def correct_types(df, column='SO_Omschrijving'):
    """
    Preprocess the specified column in a DataFrame by replacing NaN values with an empty string
    and converting non-string values to string objects.

    Parameters:
    - df (pd.DataFrame): The input DataFrame.
    - column (str): The column to be preprocessed. Default is 'SO_Omschrijving'.

    Returns:
    - pd.DataFrame: The DataFrame with the specified column preprocessed.
    """

    df[column] = df[column].fillna('')
    df[column] = df[column].astype(str)
    return df

def replace_punctuation(text):
    """
    Replace punctuation in the input text.

    Parameters:
    - text (str): The input text in which punctuation will be replaced.

    Returns:
    - str: The input text with punctuation replaced.
    """
    # Replace "'s" with empty space.
    text = text.replace("'s", '')

    # Create a translation table to replace '.' and "'" with empty space, and other punctuation with spaces.
    translator = str.maketrans({'.': '', "'": '', **{p: ' ' for p in string.punctuation if p not in ['.', "'"]}})

    cleaned_text = text.translate(translator)

    return cleaned_text

def remove_numerical_values(text):
    """
    Remove numbers and model-related patterns from the input text.

    Parameters:
    - text (str): The input text from which numbers and model-related patterns will be removed.

    Returns:
    - str: The input text with numbers and model-related patterns removed.
    """
    # Remove standalone numbers with optional floating points; such as 154, 99.31.
    text = re.sub(r'\b\d+(\.\d+)?\b', '', text)

    # Remove ordinal numbers; such as 1e, 2ste, 3de, 4e.
    text = re.sub(r'\b\d+(e|ste|de|e)\b', '', text)

    # Remove numerical quantifiers; such as 1x OH.
    text = re.sub(r'\b\d+[xX]\b', '', text)

    return text

def stemize(text):
    """
    Perform stemming on the input text using the Dutch Snowball Stemmer.

    Parameters:
    - text (str): The input text to be stemmed.

    Returns:
    str: The stemmed text.

    Example:
    >>> stemize("This is an example text for stemming.")
    'thi is an exampl text for stem.'
    """
    stemmer = SnowballStemmer("dutch")
    tokens = word_tokenize(text)
    text = ' '.join([stemmer.stem(token) for token in tokens])
    return text

def normalize_lookups():
    """
    Normalize and preprocess the global lookup lists.

    This function performs the following operations on each global lookup list:
    1. Orders lookup lists by length in descending order.
    2. Initializes the Dutch Snowball Stemmer.
    3. Replaces punctuations using the `replace_punctuation` function.
    4. Removes numerical values using the `remove_numerical_values` function.
    5. Applies stemming using the `stemize` function.
    6. Converts the resulting list to a set.

    Note: The original lookup lists are modified in-place.

    Returns:
    None
    """
    # Get all lookup lists using regular expression.
    lookup_lists = [var for var in globals() if re.match(r'^lookup_', var)]

    # Initialize stemmer.
    # stemmer = SnowballStemmer("dutch")

    for lookup_list_name in lookup_lists:

        lookup_list = globals()[lookup_list_name]

        # Replace punctuations, remove numerical values, and apply stemming.
        normalized_list = [stemize(remove_numerical_values(replace_punctuation(word))) for word in lookup_list]

        # Convert to set.
        lookup_list.clear()
        lookup_list.extend(set(normalized_list))

def group_items(description):
    """
    Group items in a description based on predefined lookup lists.

    Parameters:
    - description (str): The input description to be categorized.

    Returns:
    str: The category type of the description based on predefined lookup lists.
         If no match is found, 'Unknown' is returned.

    Example:
    >>> group_items("This is a description containing ventilation keywords.")
    'Ventilation'
    """
    # Get all lookup lists using regular expression.
    lookup_lists = [var for var in globals() if re.match(r'^lookup_', var)]

    # Order lookup lists by length in descending order.
    lookup_lists = sorted(lookup_lists, key=lambda x: len(globals()[x]), reverse=True)

    for lookup_list_name in lookup_lists:
        lookup_list = globals()[lookup_list_name]

        for word in lookup_list:
            if word in description:
                type_name = module_names[lookup_list_name.split('_')[1]]
                return type_name
    return 'Unknown'

def rules_to_coordinates(rules):
    """
    Convert association rules to coordinates.

    Parameters:
    - rules (pd.DataFrame): DataFrame containing association rules with 'antecedents', 'consequents', and other columns.

    Returns:
    - pd.DataFrame: DataFrame with 'antecedent', 'consequent', and 'rule' columns representing coordinates.
    """

    # Extract the first item from antecedents and consequents.
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent: list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent: list(consequent)[0])

    # Assign rule index to a new column 'rule'.
    rules['rule'] = rules.index

    # Select relevant columns for coordinates.
    coords = rules[['antecedent', 'consequent', 'rule']]

    return coords

def contains_word_regex(sentence, target_word):
    """
    Check if a given word is present in a sentence using regex.

    Parameters:
    - sentence (str): The input sentence to check.
    - target_word (str): The word to look for in the sentence.

    Returns:
    - bool: True if the word is found, False otherwise.
    """
    # Construct a regex pattern to match the whole word, case-insensitive.
    pattern = r'\b' + re.escape(target_word) + r'\b'
    
    # Use re.search to find the pattern in the sentence.
    match = re.search(pattern, sentence, flags=re.IGNORECASE)
    
    # Return True if a match is found, False otherwise.
    return bool(match)

# %%
lookup_ventilation = [
    "lbk",
    "luchtbehandeling",
    "luchtbehandelen",
    "luchbehandeling",
    "luchtbehandeling",
    "ventilatiesysteem",
    "ventilatie",
    "luchtklep",
    "stoombevochtiger",
    "stoombevochtiging",
    "bevochtiger",
    "toevoerventilator",
    "afvoerventilator",
    "ventilatormotor",
    "dakventilatoren",
    "Dakventilator",
    "Afzuiventilator",
    "wiel",
    "afzuigvent",
    "Vsnaren",
    "V snaren",
    "filters",
    "snaarbreuk",
    "condensafvoer",
    "condensor",
    "filter",
    "Luchtbeh",
    "LBH",
    "vorst",
    "verwarmingsbatterij",
    "stoomvochtiger",
    "luchtdebiet",
    "luchtzakken",
    "fancoil",
    "splitunit",
    "fancoil",
    "splitunit",
    "fancoil",
    "split-unit"
]
lookup_cooling = [
    "airco",
    "aircos",
    "drogekoeler",
    "koelmachine",
    "koeling",
    "KM",
    "koelunit",
    "koelinstallatie",
    "topcooling",
    "gkw",
    "koeltoren",
    "chillers",
    "drycooler",
    "koelplafond",
    "koelklep",
    "koelwaterpomp",
    "carrier",
    "DX koeler",
    "DXkoeler",
    "draaikoeler",
    "condensventilator",
    "chiller",
    "koelventilator",
    "Condensorventilator",
    "condenser"
]
lookup_heating = [
    "ketel",
    "CV",
    "c.v.",
    "c.v",
    "Kachel",
    "verwarming",
    "radiatoren",
    "radiator",
    "vloerverwarming",
    "rookgasventilator"
]
lookup_fireSafety = [
    "brandmeld",
    "rookmelder",
    "branddeur",
    "brandklep",
    "brandweer",
    "brandhaspel",
    "brandblus",
    "ontruiming",
    "Brandventilatoren",
    "trappenhuis"
]
lookup_entrance = [
    "toegangspoort",
    "tourniqet",
    "paslezer","tourniquet",
    "tourniqeut",
    "tourniqut",
    "toegang",
    "Toerniqet",
    "tourniget",
    "garagedeur",
    "schuifhek",
    "slagboom"
]
lookup_shading = [
    "zonwering",
    "zonneschermen",
    "zonnewering"
]
lookup_sanitary = [
    "toilet",
    "WC",
    "urinoir",
    "wastafel",
    "sanitair",
    "wasbak",
    "afvoer"
]
lookup_heatPump = [
    "warmtepomp",
    "warmte pomp",
    "WKO"
]
lookup_lighting = [
    "verlichting",
    "lamp",
    "Tl-buis",
    "licht",
    "tlarmatuur",
    "tlbuizen",
    "armatuur",
    "armaturen",
    "armanturen"
]
lookup_elevator = [
    "Lift"
]

lookup_wkk = [
    "WKK"
]
lookup_bms = [
    "GBS",
    "Data",
    "logger",
    "lon",
    "BMC",
    "priva",
    "software",
    "regeling",
    "hardware",
    "regelkast",
    "RK 1",
    "rk5",
    "rk2",
    "RK5",
    "rk3",
    "Rk 3",
    "rk4",
    "rk 4",
    "rk1",
    "rk2",
    "rk6",
    "rk 6",
    "RK7",
    "sensor",
    "regelaar",
    "opnemer",
    "thermostaat",
    "meting",
    "onderstation",
    "Kloktijden",
    "kastventilatoren",
    "kastventilatoren",
    "kastventilator",
    "Kastventilator"
]


lookup_waterDistribution = [
    "regelklep",
    "driewegklep",
    "TSA",
    "Warmtewisselaar",
    "pomp",
    "hydrofoor",
    "expansie",
    "drukvat",
    "waterleiding",
    "3wegklep",
    "transportnet"
]

lookup_office = [
    "werkvoorbereiding",
    "Contractbeheerder",
    "materiaal",
    "Onderaanneming",
    "Werkvoorbereider",
    "kantoor",
    "Materiaalbon",
    "Urenbon",
    "Contractbegeleiding",
    "Contractbeheer",
    "overleg",
    "Meet-enregeltechniek",
    "Inlenen",
    "Weekplanning",
    "calculatie",
    "Onderaannemering",
    "contractmanager",
    "Contractmanagement",
    "Onderaannemer"
]

lookup_domesticWater = [
    "warm water",
    "ww",
    "w.w.",
    "w.w",
    "warmtapwater",
    "warmwater",
    "boiler"
]

loopup_faultRedemption = [
    "Storingsafkoop",
    "Afkoopstoringen",
    "Verrekening afkoop"
]

lookup_regularMaintenance = [
    "onderhoud",
    "inspectie",
    "OH",
    "OHD",
    "controle",
    "Preventief",
    "testen",
    "Bedrijfvoering",
    "Bedrijfsvoering"
]

lookup_complaints = [
    "klachten",
    "klacht",
    "te warm",
    "tekoud",
    "luchtvochtigheid",
    "klimaatbeheersing",
    "klimaat",
    "teheet",
    "benauwd",
    "tocht",
    "R.V.",
    "ergkoud",
    "RV telaag",
    "lekkage",
    "Ruimtevochtigheid",
    "erg warm",
    "erg koud"
]
module_names = {
    "complaints": "Complaints",
    "regularMaintenance": "Regular Maintenance",
    "faultRedemption": "Fault Redemption",
    "domesticWater": "Domestic Water",
    "office": "Office",
    "waterDistribution": "Water Distribution",
    "bms": "BMS",
    "wkk": "WKK",
    "elevator": "Elevator",
    "lighting": "Lighting",
    "heatPump": "Heat Pump",
    "sanitary": "Sanitary",
    "fireSafety": "Fire Safety",
    "shading": "Shading",
    "entrance": "Entrance",
    "ventilation": "Ventilation",
    "heating": "Heating",
    "cooling": "Cooling"
}

# %%
normalize_lookups()

# %%
path = './Navision Serviceorder data.xlsx'

# Read the Excel file into a DataFrame.
df_so = pd.read_excel(path)

df_so.reset_index(drop=True, inplace=True)

# print(df_so.info())

columns_to_select = ['SO_Omschrijving', 'SO_Orderdatum (Begindatum)', 'Order technisch gereed (Einddatum)', 'Factuurkosten SO']
df_so = df_so[columns_to_select]

df_so.head()
# Out:
#                                SO_Omschrijving  SO_Orderdatum (Begindatum)  \
# 0         storing stoombevochtiger ruimte 4.29                       44608
# 1  Wasbak pantry ruimte 4.38 loopt slecht door                       44624
# 2           Storing bevochtiger van LBK-Links.                       44627
# 3        Afzuig schakelaar werkt niet. Keuken.                       44704
# 4            Snaarbreuk afzuigvent. LBK rechts                       44742
#
#    Order technisch gereed (Einddatum)  Factuurkosten SO
# 0                             44609.0            154.18
# 1                             44624.0            229.58
# 2                             44628.0            188.14
# 3                             44704.0            250.17
# 4                             44746.0            447.16

# %% [markdown]
# **Data Cleaning**

# %%
# Create a copy from the original dataset.
df_so_cleaned = correct_types(df_so, column='SO_Omschrijving')

# Replace punctuations.
df_so_cleaned['SO_Omschrijving'] = df_so_cleaned['SO_Omschrijving'].apply(replace_punctuation)

# Remove numerical values.
df_so_cleaned['SO_Omschrijving'] = df_so_cleaned['SO_Omschrijving'].apply(remove_numerical_values)

# Remove Dutch stop words.
stop_words = set(stopwords.words('dutch'))
stop_words.add('via')
df_so_cleaned['SO_Omschrijving'] = df_so_cleaned['SO_Omschrijving'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))

# Stemize the text.
df_so_cleaned['SO_Omschrijving'] = df_so_cleaned['SO_Omschrijving'].apply(stemize)

df_so_cleaned.head()
# Out:
#                     SO_Omschrijving  SO_Orderdatum (Begindatum)  \
# 0    storing stoombevochtiger ruimt                       44608
# 1  wasbak pantry ruimt loopt slecht                       44624
# 2      storing bevochtiger lbk link                       44627
# 3       afzuig schakelar werkt keuk                       44704
# 4   snaarbreuk afzuigvent lbk recht                       44742
#
#    Order technisch gereed (Einddatum)  Factuurkosten SO
# 0                             44609.0            154.18
# 1                             44624.0            229.58
# 2                             44628.0            188.14
# 3                             44704.0            250.17
# 4                             44746.0            447.16

# %%
df_so_cleaned['target'] = df_so_cleaned['SO_Omschrijving'].apply(group_items)
categorized_count = 0
for _, value in module_names.items():
    categorized_count = categorized_count + len(df_so_cleaned["target"][df_so_cleaned["target"] == value])
    print(f'{value} count: {len(df_so_cleaned["target"][df_so_cleaned["target"] == value])}')
# Out:
# Complaints count: 1834
# Regular Maintenance count: 110
# Fault Redemption count: 0
# Domestic Water count: 930
# Office count: 80
# Water Distribution count: 655
# BMS count: 1976
# WKK count: 1
# Elevator count: 374
# Lighting count: 885
# Heat Pump count: 68
# Sanitary count: 584
# Fire Safety count: 81
# Shading count: 22
# Entrance count: 59
# Ventilation count: 604
# Heating count: 1848
# Cooling count: 818

# %%
df_so_ventilation = df_so_cleaned[df_so_cleaned["target"].isin(["Ventilation"])]
df_so_cooling = df_so_cleaned[df_so_cleaned["target"].isin(["Cooling"])]
df_so_heating = df_so_cleaned[df_so_cleaned["target"].isin(["Heating"])]
df_so_cleaned.head()
# Out:
#                     SO_Omschrijving  SO_Orderdatum (Begindatum)  \
# 0    storing stoombevochtiger ruimt                       44608
# 1  wasbak pantry ruimt loopt slecht                       44624
# 2      storing bevochtiger lbk link                       44627
# 3       afzuig schakelar werkt keuk                       44704
# 4   snaarbreuk afzuigvent lbk recht                       44742
#
#    Order technisch gereed (Einddatum)  Factuurkosten SO       target
# 0                             44609.0            154.18  Ventilation
# 1                             44624.0            229.58     Sanitary
# 2                             44628.0            188.14  Ventilation
# 3                             44704.0            250.17          BMS
# 4                             44746.0            447.16  Ventilation

# %%
# Split transaction strings into lists.
transactions = df_so_ventilation['SO_Omschrijving'].apply(lambda t: t.split(' '))
# Convert DataFrame column into list of strings.
transactions_ventilation = list(transactions)
print(transactions_ventilation)

transactions = df_so_cooling['SO_Omschrijving'].apply(lambda t: t.split(' '))
transactions_cooling = list(transactions)
print(transactions_cooling)

transactions = df_so_heating['SO_Omschrijving'].apply(lambda t: t.split(' '))
transactions_heating = list(transactions)
print(transactions_heating)
# Out:
# [['storing', 'stoombevochtiger', 'ruimt'], ['storing', 'bevochtiger', 'lbk', 'link'], ['snaarbreuk', 'afzuigvent', 'lbk', 'recht'], ['lbk', 'recht', 'stoomomvormer', '100sb01'], ['stoomomvormer', 'lbk', 'recht'], ['rk', 'lbk', 'link', 'afzuigventilator', '100av01'], ['mer', 'ruimt', 'rk', 'lbk', 'link', 'communicatie', 'alarm'], ['snaarbreuk', 'afzuigvent', 'rk', 'lbk', 'recht'], ['storing', 'snaarbreuk', 'afzuigvent', '100pdt02'], ['snaarbreuk', 'afzuigvent'], ['lbk', 'recht', 'snaarbreuk'], ['stoomomvormer', 'rk3', 'lbk', 'link', 'storing'], ['storing', 'lbk'], ['fancoil', 'unit', 'mak', 'lawaai'], ['ventilatiesystem', 'stat', 'storing'], ['afzuigventilator', 'produktie', 'start'], ['storing', 'frequentieregelar', 'ventilatie', 'keuk'], ['luchtbehandelingsystem', 'valt', 'sted', 'storing'], ['pomp', 'storing', 'fancoil'], ['pomp', 'storing', 'fancoil'], ['ruimt', 'lbk', 'melding'], ['storing', 'stoomvormer', 'lbk'], ['ruimtetemp', 'ruimt', 'lbk', 'max', 'gr'], ['lbk', 'schakel'], ['spoed', 'storing', 'luchtbehandelingsystem'], ['ra', 'storing', 'koelmachin', 'luchtbehandel'], ['ra', 'storing', 'koelmachin', 'luchtbehandel'], ['koelmachin', 'luchtbehandelingskast', 'uitgevall'], ['koelmachin', 'luchtbehandelingskast', 'uitgevall'], ['ra', 'snaarbreuk', 'lbk', 'bg', 't', 'm'], ['nazien', 'lbk', 'kantor', 'verd', '1t', 'm7'], ['mp', 'storing', 'luchtbehandel', 'restaurant'], ['mp', 'storing', 'vorstthermostat'], ['jb', 'storing', 'luchtbehandel'], ['jb', 'storing', 'luchtbehandel'], ['ra', 'lekkag', 'lbk', 'verd', 'ruimt'], ['mp', 'lamp', 'defect', 'verd', 'lekkag', 'luchtbehandel'], ['ra', 'klimaatklacht', 'restaurant', 'bevochtiger', 'stor'], ['ra', 'klimaatklacht', 'restaurant', 'bevochtiger', 'stor'], ['mp', 'storing', 'hygromatik', 'lucht', 'bevochtiger'], ['nazien', 'luchtbehandel', 'ruimt'], ['lbk', 'geeft', 'hog', 'urgentie', 'valt', 'reset'], ['storing', 'lbk', 'bg', 't', 'm', 'verd'], ['luchtbehandel', 'loopt', 'bpm'], ['storing', 'lbk', 'v', 'snar', 'eraf'], ['lbk', 'komt', 'diver', 'mal', 'achter', 'elkar', 'storing'], ['mogelijk', 'snaarbreuk', 'luchtbehandel', 'ruimt'], ['knop', 'brand', 'rod', 'rk2', 'lbh', 'urgent'], ['spoed', 'verwarm', 'lbk', 'bg', 'tm', 'verd', 'werkt'], ['kapot', 'v', 'snar', 'lbk', 'luchtbehandel', 'centraleha'], ['lbk', 'doet', 'maakt', 'allen', 'brommend', 'geluid'], ['cv', 'afd', 'puza', 'snaarbreuk', 'lbk', 'centr', 'hal'], ['storing', 'urgent', 'lbk', 'foutcodes'], ['lbk', 'tempratur', 'schommelt', 'hel', 'erg'], ['vervang', 'ventilatormotor', 'lg', 'unit'], ['vervang', 'ventilatormotor', 'lg', 'unit'], ['jh', 'luchtbehandel', 'maakt', 'rar', 'geluid'], ['lbk', 'blaast', 'koud', 'lucht'], ['ernstig', 'lekkag', 'condensor', 'airco'], ['ra', 'storing', 'urgent', 'lbk'], ['vervang', 'motor', 'lbk'], ['hz', 'storing', 'ventilatie'], ['iv', 'lbk', 'storing'], ['iv', 'lbk', 'storing'], ['ra', 'ventilatie', 'defect'], ['ev', 'storing', 'ventilatiesystem'], ['iv', 'ventilatie', 'storing', 'inbr', 'install'], ['iv', 'ventilatie', 'storing', 'inbr', 'install'], ['jb', 'kapp', 'klapper', 'dak', 'ventilatie'], ['ra', 'lbk', 'storing'], ['mp', 'plafond', 'ventilatie', 'maakt', 'tikkend', 'geluid'], ['luchtventilatie', 'werkt', 'blaast', 'warm', 'lucht'], ['luchtventilatie', 'werkt', 'blaast', 'warm', 'lucht'], ['storing', 'ventilatiesystem'], ['lekkag', 'ventilatiesystem'], ['storing', 'ventilatiesystem'], ['daklekkag', 'lbk'], ['daklekkag', 'los', 'afdekplat', 'ventilatieunit'], ['storing', 'ventilatiesystem'], ['ventilatiesystem', 'voert', 'warm', 'lucht', 'af'], ['storing', 'ventilatiesystem'], ['storing', 'ventilatiesystem'], ['lbk', 'geeft', 'urgent', 'storing', 'vuilfilter'], ['mp', 'lbk', 'storing'], ['mp', 'opnieuw', 'storing', 'luchtbehandelingssystem'], ['snaarbreuk', 'lbl', 'defect', 'buitenluchtklep'], ['lbk'], ['tennet', 'storing', 'airco', 'lbk', 'server', 'ruimt'], ['central', 'hal', 'erg', 'warm', 'lbk', 'nazien'], ['vorstthermostat', 'lbk', 'nakijk', 'stat', 'hand'], ['luchtbehande ...
# [['computair', 'ruimt', 'koeling', 'plas', 'water', 'server'], ['rookmelder', 'toevoer', 'rookkanal', 'functioneerd'], ['airco', 'unit', 'lijkt', 'strom', 'krijg'], ['lekkag', 'airco', 'binnendel'], ['rookmelder', 'toevoer', 'rookkanal', 'functioneerd'], ['secundair', 'koeling', 'doet'], ['koeling', 'blaast', 'koud', 'lucht'], ['koeling', 'blaast', 'koud', 'lucht'], ['koelmachin', 'storing'], ['koelmachin', 'storing'], ['melding', 'min', 'installatiedruk', 'koelmachin'], ['storing', 'koelmachin', 'vloeistofhok'], ['iv', 'airco', 'defect'], ['ra', 'storing', 'koelmachin'], ['ra', 'koelmachin', 'storing'], ['jh', 'storing', 'koelmachin'], ['jh', 'storing', 'koelmachin'], ['jb', 'lekkag', 'koelplafond', 'verd'], ['jh', 'airco', 'defect'], ['koelinstallatie', 'stat', 'alarm', 'cod', 'e0003'], ['storing', 'koelmachin'], ['storing', 'koelmachin'], ['koelplafond', 'voel', 'koud'], ['nieuw', 'geplaatst', 'koeling', 'ruitjes', 'afstell', 'hog'], ['storing', 'koelmachin', 'water', 'exchanger', 'flow', 'failur'], ['mp', 'lekkag', 'vanaf', 'dak', 'koelmachin'], ['mp', 'lekkag', 'vanaf', 'dak', 'koelmachin'], ['beid', 'koelmachines', 'stan', 'storing', 'urgentie', 'hog'], ['storing', 'koelmachin'], ['storing', 'koeling'], ['koeling', 'storing'], ['beid', 'koelinstallaties', 'storing'], ['koelmachin', 'storing'], ['koelmachin', 'storing'], ['koelmachin', 'storing'], ['koelmachin', 'hd', 'storing', 'galetti'], ['koelmachin', 'storing'], ['lekkag', 'leiding', 'airco', 'verdiep', 'afd', 'gegevensb'], ['gkw', 'lekkag', 'drukvat'], ['koelmachin', 'valt', 'sted'], ['groep', 'airco', 'valt'], ['airco', 'portierslog', 'storing'], ['lekkag', 'restaurant', 'airco', 'plafond'], ['lekkag', 'restaurant', 'airco', 'plafond'], ['lekkag', 'restaurant', 'airco', 'plafond'], ['storing', 'airco', 'hoger', 'afzeker'], ['storing', 'airco'], ['flow', 'storing', 'chiller', 'koudwater', 'machin'], ['flow', 'storing', 'chiller', 'koudwater', 'machin'], ['storing', 'koeling', 'goederenontvangst'], ['storing', 'airco', 'hoger', 'afzeker'], ['jb', 'wederom', 'airco', 'storing'], ['mp', 'airco', 'serverruimt', 'storing'], ['mp', 'storing', 'airco', 'kantin', 'vergaderruimt'], ['airco', 'kantor', 'td', 'doet'], ['storing', 'airco', 'dames', 'kleedkamer'], ['mp', 'storing', 'airco'], ['mp', 'storing', 'airco'], ['mp', 'storing', 'airco', 'spoelkeuk', 'kantor'], ['vervang', 'automat', 'airco', 'spoelkeuk', 'kantor'], ['storing', 'airco', 'ruimt', 'v238a'], ['storing', 'airco', 'restaurant', 'vergaderzal'], ['defect', 'airco', 'verwarm'], ['mp', 'lekkag', 'airco', 'bedrijsrestaurant'], ['storing', 'koeling'], ['storing', 'airco', 'melding', 'ch61'], ['storing', 'airco', 'bezoek', 'oa', 'juni'], ['airco', 'storing', 'spoelkeuk', 'storing', 'ch61'], ['storing', 'airco'], ['airco', 'kantor', 'uitgevall'], ['airco', 'dak', 'omgewaaid'], ['storing', 'airco', 'afvoerwatercondenser', 'accu', 'hok', 'ver'], ['lekkag', 'airco'], ['koelmachin', 'oudbouw', 'tran', 'storing'], ['debiet', 'storing', 'koelmachin'], ['airco', 'geeft', 'storing', 'ch61', 'doet'], ['airco', 'lekt'], ['airco', 'kantor', 'kruidenier'], ['airco', 'emballagekantor', 'maakt', 'herrie'], ['lekkag', 'airco', 'kantor', 'facilitair', 'dienst'], ['airco', 'cod', 'ch61in', 'kantor', 'otto'], ['airco'], ['ra', 'airco', 'defect', 'kantin'], ['ra', 'airco', 'defect', 'kantin'], ['iv', 'lekkag', 'koeling'], ['ra', 'airco', 'kassameubel', 'koelt'], ['lekkag', 'koelingssystem'], ['iv', 'koelinstallatie'], ['koeling', 'kassa', 'defect'], ['jb', 'koeling', 'kassa'], ['ra', 'lekkend', 'airco', 'vestiginsmanager'], ['ra', 'lekkag', 'airco', 'adm', 'kantor'], ['ra', 'storing', 'airco', 'personeelsruimt'], ['mp', 'airco', 'blaast', 'allen', 'warmt', 'lucht'], ['lekkag', 'airco'], ['lekkag', 'airco', 'urinoir'], ['storing', 'airco', 'kantin'], ['start', 'gered', 'mak', 'adiabatisch', 'koeling'], ['storing', 'airco'], ['storing', 'airco', 'kantor', 'valt', 'minut'], ['airco', 'koelt', 'goed', 'lekt'], ['storing', 'airco'], ['stori ...
# [['uitval', 'verwarm', 'svp', 'contact'], ['verwarm', 'doet'], ['storing', 'verwarm', 'spuitcabin'], ['cv', 'storing'], ['radiator', 'warm'], ['storing', 'cv', 'ketel'], ['cv', 'storing'], ['cv', 'ketel', 'geeft', 'foutcod', 'grag', 'nakijk'], ['cv', 'ketel', 'geeft', 'foutcod', 'grag', 'nakijk'], ['verwarm'], ['storing', 'vaillant', 'ketel', 'torenpad', 'wachter'], ['lekkend', 'radiator'], ['lekkend', 'radiator'], ['thermostaatknop', 'defect', 'verwarm', 'goederenontvang'], ['iv', 'ketel', 'storing'], ['storing', 'ketel'], ['cv'], ['storing', 'verwarmingsinstallatie'], ['cv', 'installatie', 'bestuursafd', 'bromt', 'erg', 'hard'], ['uitvall', 'ketel'], ['verwarm'], ['cv', 'storing', 'ketel'], ['storing', 'ketel', 'technisch', 'ruimt'], ['storing', 'ketel'], ['radiator', 'warm'], ['kleedkamer', 'verwarm'], ['ker', 'storing', 'cv', 'ketel', 'water', 'bijvull'], ['cv', 'waterdruk', 'lag'], ['ketel', 'stat', 'storing'], ['verwarm', 'warm'], ['storing', 'cv', 'installatie'], ['beid', 'ketel', 'gev', 'water', 'erin'], ['storing', 'cv'], ['storing', 'cv'], ['cv'], ['cv'], ['ketel', 'achtergevel', 'storing'], ['ketel', 'achtergevel', 'storing'], ['ketel', 'defect'], ['ketel', 'defect'], ['ketel', 'maakt', 'geluid'], ['ketel', 'maakt', 'geluid'], ['storing', 'ketel', 'achtergevel', 'hog'], ['storing', 'ketel'], ['iv', 'cv'], ['ra', 'storing', 'ketel'], ['ra', 'storing', 'ketel'], ['mp', 'ketel', 'storing'], ['mp', 'ketel', 'storing'], ['storing', 'ketel', 'achtergevel'], ['iv', 'verwarm', 'lg', 'unit', 'ligt', 'eruit'], ['iv', 'verspand', 'st', 'ketel', 'achtergevel'], ['iv', 'verspand', 'st', 'ketel', 'achtergevel'], ['iv', 'verspand', 'st', 'ketel', 'achtergevel'], ['jb', 'cv', 'kantin', 'vergaderruimt'], ['iv', 'storing', 'ketel', 'achtergevel', 'verspand'], ['iv', 'storing', 'ketel', 'achtergevel', 'verspand'], ['iv', 'cv', 'storing'], ['mp', 'storing', 'ketel', 'achtergevel'], ['iv', 'cv', 'storing'], ['ra', 'cv', 'storing'], ['jo', 'verwarm', 'lekt'], ['lag', 'druk', 'cv'], ['lag', 'druk', 'cv'], ['spoed', 'verwarm', 'storing', 'buitenvoeler'], ['voordruk', 'alarm', 'kw', 'pand', 'ins', 'dr', 'ketel'], ['storing', 'ketel', 'achtergevel'], ['verwarm', 'pand', 'doet'], ['vooralarm', 'min', 'installatiedruk', 'ketel', 'kw', 'pand'], ['min', 'gr', 'waard', 'centr', 'aanvoer', 'temp', 'ketel'], ['ketel', 'storing', 'ketel', 'achtergevel'], ['binnendel', 'ruimt', 'verwarmd'], ['ketelstor', 'os'], ['storing', 'verwarm'], ['st', 'verwarm'], ['storing', 'cv', 'ketel', 'pand', 'kw', 'remeha'], ['vloer', 'verwarm', 'boort', 'gang', 'instal'], ['ketel', 'start'], ['cv', 'kantin', 'vermoed', 'uitval', 'groep'], ['storing', 'ketelhuis'], ['ketel', 'valt', 'sted'], ['ketelhuis', 'storing'], ['storing', 'ketelhuis'], ['storing', 'daikin', 'verwarm'], ['uitval', 'cv', 'social', 'ruimtes'], ['cv', 'gaslucht'], ['storing', 'cv', 'ketel', 'status'], ['verwarm'], ['radiator', 'blijft', 'doorbrand'], ['cv', 'storing'], ['iv', 'hulp', 'nodig', 'opstart', 'ketel'], ['iv', 'hulp', 'nodig', 'opstart', 'ketel'], ['ev', 'cv'], ['mp', 'cv', 'uitgevall'], ['jh', 'cv'], ['cv'], ['cv', 'ketel', 'storing'], ['ra', 'cv', 'storing'], ['ra', 'cv', 'storing'], ['brander', 'defect', 'cv', 'ketel'], ['jh', 'storing', 'cv'], ['iv', 'storing', 'cv', 'ketel'], ['jb', 'storing', 'cv', 'ketel'], ['ra', 'storing', 'cv', 'stadsverwarm'], ['jh', 'problem', 'ketel'], ['jh', 'problem', 'ketel'], ['mp', 'storing', 'cv', 'ketel'], ['ra', 'storing', 'cv', 'ketel'], ['mp', 'storing', 'cv', 'start', 'goed'], ['mp', 'storing', 'cv', 'temp', 'hog', 'winkel'], ['jb', 'beid', 'ketel', 'wederom', 'storing'], ['cv', 'ketel', 'stan', 'storing'], ['jo', 'storing', 'cv', 'ketel'], ['storing', 'cv', 'ketel'], ['opnieuw', 'storing', 'cv', 'ketel'], ['cv', 'system', 'eerder', 'opgestart', 'maandag'], ['waterdruk', 'cv', 'installatie', 'lag'], ['storing', 'cv', 'ketel'], ['storing', 'cv', 'ketel'], ['cv', 'ketel', 'blijft', 'storing', 'vall'], ['storing', 'cv', 'ketel'], ['storing', 'cv', 'ketel ...

# %%
# Instantiate transaction encoder and identify unique items in transactions.
encoder = TransactionEncoder().fit(transactions_ventilation)
# One-hot encode transactions.
onehot_ventilation = encoder.transform(transactions_ventilation)
onehot_ventilation = pd.DataFrame(onehot_ventilation, columns=encoder.columns_)

encoder = TransactionEncoder().fit(transactions_cooling)
onehot_cooling = encoder.transform(transactions_cooling)
onehot_cooling = pd.DataFrame(onehot_cooling, columns=encoder.columns_)

encoder = TransactionEncoder().fit(transactions_heating)
onehot_heating = encoder.transform(transactions_heating)
onehot_heating = pd.DataFrame(onehot_heating, columns=encoder.columns_)
onehot_heating
# Out:
#       02ke02  03ke01  03ke02  03pt01     0a  10kt1  111ke01  111ke05  111ke06  \
# 0      False   False   False   False  False  False    False    False    False
# 1      False   False   False   False  False  False    False    False    False
# 2      False   False   False   False  False  False    False    False    False
# 3      False   False   False   False  False  False    False    False    False
# 4      False   False   False   False  False  False    False    False    False
# ...      ...     ...     ...     ...    ...    ...      ...      ...      ...
# 1843   False   False   False   False  False  False    False    False    False
# 1844   False   False   False   False  False  False    False    False    False
# 1845   False   False   False   False  False  False    False    False    False
# 1846   False   False   False   False  False  False    False    False    False
# 1847   False   False   False   False  False  False    False    False    False
#
#       12kg1  ...    zit  zithoek   zoem  zoemend  zoemer  zolder   zorg  \
# 0     False  ...  False    False  False    False   False   False  False
# 1     False  ...  False    False  False    False   False   False  False
# 2     False  ...  False    False  False    False   False   False  False
# 3     False  ...  False    False  False    False   False   False  False
# 4     False  ...  False    False  False    False   False   False  False
# ...     ...  ...    ...      ...    ...      ...     ...     ...    ...
# 1843  False  ...  False    False  False    False   False   False  False
# 1844  False  ...  False    False  False    False   False   False  False
# 1845  False  ...  False    False  False    False   False   False  False
# 1846  False  ...  False    False  False    False   False   False  False
# 1847  False  ...  False    False  False    False   False   False  False
#
#       zorgcluster   zwar  zwembad
# 0           False  False    False
# 1           False  False    False
# 2           False  False    False
# 3           False  False    False
# 4           False  False    False
# ...           ...    ...      ...
# 1843        False  False    False
# 1844        False  False    False
# 1845        False  False    False
# 1846        False  False    False
# 1847        False  False    False
#
# [1848 rows x 903 columns]

# %% [markdown]
# **Algorithm**

# %% [markdown]
# Ventilation

# %%
# Compute frequent itemsets using the Apriori algorithm.
frequent_itemsets_ventilation = apriori(onehot_ventilation, 
                            min_support =  0.01,
                            use_colnames = True,
                            verbose = 1)

print(len(frequent_itemsets_ventilation))

# frequent_itemsets_ventilation = frequent_itemsets_ventilation[frequent_itemsets_ventilation['itemsets'].apply(lambda x: len(x)) > 1]
frequent_itemsets_ventilation = frequent_itemsets_ventilation.sort_values(by=['support'], ascending=False).reset_index(drop=True)
frequent_itemsets_ventilation.head(50)
# Out:
# Processing 8 combinations | Sampling itemset size 4 32
# 89
#      support                     itemsets
# 0   0.324503                        (lbk)
# 1   0.302980                    (storing)
# 2   0.162252                 (ventilatie)
# 3   0.120861               (lbk, storing)
# 4   0.094371              (luchtbehandel)
# 5   0.077815                         (mp)
# 6   0.064570           (ventilatiesystem)
# 7   0.057947                     (filter)
# 8   0.046358                      (werkt)
# 9   0.044702                     (lekkag)
# 10  0.039735                    (vervang)
# 11  0.038079                         (ra)
# 12  0.036424        (storing, ventilatie)
# 13  0.036424                 (snaarbreuk)
# 14  0.036424                      (maakt)
# 15  0.034768                         (jb)
# 16  0.033113                     (defect)
# 17  0.031457                     (urgent)
# 18  0.031457                       (unit)
# 19  0.031457     (luchtbehandel, storing)
# 20  0.029801                      (geeft)
# 21  0.028146                      (lucht)
# 22  0.028146                     (blaast)
# 23  0.026490                     (lawaai)
# 24  0.026490                         (iv)
# 25  0.026490            (urgent, storing)
# 26  0.026490                     (nazien)
# 27  0.026490           (stoombevochtiger)
# 28  0.024834                         (jh)
# 29  0.024834                  (uitgevall)
# 30  0.023179                       (koud)
# 31  0.023179          (werkt, ventilatie)
# 32  0.023179            (vorstthermostat)
# 33  0.023179                 (warmtewiel)
# 34  0.023179                        (hog)
# 35  0.023179            (lbk, snaarbreuk)
# 36  0.023179                    (lbk, mp)
# 37  0.021523                      (ruimt)
# 38  0.019868              (maakt, lawaai)
# 39  0.019868                (lbk, urgent)
# 40  0.019868  (ventilatiesystem, storing)
# 41  0.019868                  (schietban)
# 42  0.019868                     (gebouw)
# 43  0.018212                (ra, storing)
# 44  0.018212                       (stat)
# 45  0.018212                    (zwembad)
# 46  0.018212                  (condensor)
# 47  0.018212                (storing, mp)
# 48  0.018212              (lucht, blaast)
# 49  0.016556             (geeft, storing)

# %%
# Compute all association rules for frequent_itemsets.
rules_ventilation = association_rules(frequent_itemsets_ventilation, 
                            metric = "lift", 
                         	min_threshold = 1)

rules_ventilation = rules_ventilation.sort_values(by=['lift'], ascending=False).reset_index(drop=True)
print(len(rules_ventilation))
# rules_ventilation.head(50)

rules_one_consequent = rules_ventilation[rules_ventilation['antecedents'].apply(len) == 2]
print(len(rules_one_consequent))
rules_one_consequent.head(60)
# Out:
# 66
# 6
#           antecedents consequents  antecedent support  consequent support  \
# 1      (koud, blaast)     (lucht)            0.011589            0.028146
# 3       (lucht, koud)    (blaast)            0.014901            0.028146
# 5     (lucht, blaast)      (koud)            0.018212            0.023179
# 18     (lbk, storing)    (urgent)            0.120861            0.031457
# 25      (lbk, urgent)   (storing)            0.019868            0.302980
# 41  (urgent, storing)       (lbk)            0.026490            0.324503
#
#      support  confidence       lift  leverage  conviction  zhangs_metric
# 1   0.011589    1.000000  35.529412  0.011263         inf       0.983250
# 3   0.011589    0.777778  27.633987  0.011170    4.373344       0.978391
# 5   0.011589    0.636364  27.454545  0.011167    2.686258       0.981450
# 18  0.016556    0.136986   4.354722  0.012754    1.122280       0.876271
# 25  0.016556    0.833333   2.750455  0.010537    4.182119       0.649324
# 41  0.016556    0.625000   1.926020  0.007960    1.801325       0.493878

# %% [markdown]
# **Observe Itemsets____________________________________________________________**

# %%
df_original = pd.read_excel(path)
df_original.reset_index(drop=True, inplace=True)
columns_to_select = ['SO_Omschrijving', 'SO_Orderdatum (Begindatum)', 'Order technisch gereed (Einddatum)', 'Factuurkosten SO']
df_original = df_original[columns_to_select]

# %%
word_list = list(rules_ventilation.iloc[0]['antecedents'])
indices = []
for transaction in df_so['SO_Omschrijving']:
    if all(contains_word_regex(transaction, word) for word in word_list):
        indices.append(df_so[df_so['SO_Omschrijving'] == transaction].index[0])

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(f"Original Dataset: {len(indices)} items\n{df_original.iloc[indices]['SO_Omschrijving']}")
    print(f"\nCleaned Dataset: {len(indices)} items\n{df_so.iloc[indices]['SO_Omschrijving']}")
# Out:
# Original Dataset: 73 items
# 88                        Koeling blaast geen koude lucht.
# 88                        Koeling blaast geen koude lucht.
# 100                 Geluidsklachten / lucht in installatie
# 364               (MP)storing hygromatik lucht bevochtiger
# 1181                             LBK Blaast te koude lucht
# 1315                             Blowers blazen koud lucht
# 1648                  (MP)Airco blaast alleen warmte lucht
# 1806      Luchtventilatie werkt niet, blaast warme lucht.
# 1806      Luchtventilatie werkt niet, blaast warme lucht.
# 1849                     Linker dakunit zuigt valse lucht.
# 1903               Warmelucht gordijnen blazen koude lucht
# 1905                             Heater blaast koude lucht
# 1972                  Luchtheater geeft alleen koude lucht
# 2111          ventilatiesysteem voert warme lucht niet af
# 2150                    Warmte gordijn blaast koude lucht
# 2191                            (MP) Storing lucht toevoer
# 2468              Pomp is defect + veel lucht in leidingen
# 2561         Installatie maakt veel herrie en koude lucht
# 2844     (JB) 1 van de 3 splitunits blaast geen koude l...
# 2844     (JB) 1 van de 3 splitunits blaast geen koude l...
# 2989               Geen gekoelde lucht in nieuwbouwlokalen
# 2997     Weinig lucht vanuit ventilatiesysteem gebouw 700.
# 3133        Ventilatie blaast koude lucht in. Ruimte RL116
# 3397                         (MP) koude lucht in kamer 208
# 3402                                 (EV) Geen koude lucht
# 3766                     Droge/ vieze lucht op de afname.
# 4094                          Er zit lucht in het systeem.
# 5162                        Fancoilunit blaast warme lucht
# 5195                      Storing aan de lucht behandeling
# 5347                          Alleen warme lucht uit airco
# 5815              Airco blaast geen koude lucht (unit 24).
# 5905     Storing Airco Technische ruimte warme lucht   ...
# 5914           Airco in E-timing ruimte blaast warme lucht
# 5942                    Vieze lucht bij gootsteen aanrecht
# 6011     Carrier 3.04 op verdieping blaast weer warme l...
# 6043        De carriers in beide units blazen koude lucht.
# 6046           AV-huis geen warme lucht uit unit 0.10+0.11
# 6054          De verwarming blaast alleen koude lucht 1.05
# 6062     carrier blaast weinig /geen koude lucht hoge temp
# 6072                          Geen verse lucht ingeblazen.
# 6109                       Kantoor 3.06 blaast koude lucht
# 6115     Fancoilunit ruimte 3.04 blaast alleen koude lucht
# 6148                         Vreemde/rotte lucht uit airco
# 6475                      Koude lucht uitgeblazen door LBK
# 6788                           (RA) Geen koude lucht airco
# 6809                (JB) Blowers blazen alleen koude lucht
# 7358     (EV) Ventilatie boven waterbed blaast koude lucht
# 7744           (JB) Koude lucht uit roosters grote gymzaal
# 7869                                      (JH) droge lucht
# 7951                     (MP) Temp. te hoog /  lucht droog
# 7869                                      (JH) droge lucht
# 8297                        (JH) lucht wordt niet ververst
# 8302                  (RA) Lucht in radiator. Kamer Teepan
# 8457                          Erg droge lucht in de woning
# 8540                     (MP) Temp. te hoog en droge lucht
# 9282                   (MP)droge lucht dagbestedingsruimte
# 9785                     Airco lokaal 5 blaast lauwe lucht
# 9887     Ventillatiesysteem blaast vieze lucht de wonin...
# 9992         Afzuiging blaast koude lucht in de grote zaal
# 10060      Geen goede afzuiging en geen goed lucht binnen
# 10518                 Ijle lucht, droge lucht, benauwdheid
# 10625                                 Last van droge lucht
# 10999       Airco  Expeditielokaal blaast geen koude lucht
# 11822                                Geen koude lucht meer
# 12292      Airco stuurruimte blaast geen koude lucht meer.
# 13092         Luchtbehandeling Aula blaast te koude lucht
# 13155              Geen koele lucht binnen bij de receptie
# 14067                    Muffe lucht uit ventilatiesysteem
# 15285         luchtbeh. blaas koude lucht, radiatoren warm
# 15368                            Vreemde lucht uit airco's
# 15645                      Afzuiging zuigt valse lucht aan
# 15768                  Klachten over klamme benauwde lucht
# 16024                 LBk controleren. Blaast warme lucht.
# Name: SO_Omschrijving, dtype: object
#
# Cleaned Dataset: 73 items
# 88                          koeling blaast koud lucht
# 88                          koeling blaast koud lucht
# 100                   geluidsklacht lucht installatie
# 364           mp storing hygromatik lucht bevochtiger
# 1181                            lbk blaast koud lucht
# 1315                           blower blaz koud lucht
# 1648                mp airco blaast allen warmt lucht
# 1806          luchtventilatie werkt blaast warm lucht
# 1806          luchtventilatie werkt blaast warm lucht
# 1849                   linker dakunit zuigt val lucht
# 1903               warmelucht gordijn blaz koud lucht
# 1905                         heater blaast koud lucht
# 1972               luchtheater geeft allen koud lucht
# 2111             ventilatiesystem voert warm lucht af
# 2150                  warmt gordijn blaast koud lucht
# 2191                         mp storing lucht toevoer
# 2468                        pomp defect lucht leiding
# 2561              installatie maakt herrie koud lucht
# 2844                   jb splitunit blaast koud lucht
# 2844                   jb splitunit blaast koud lucht
# 2989                     gekoeld lucht nieuwbouwlokal
# 2997      weinig lucht vanuit ventilatiesystem gebouw
# 3133         ventilatie blaast koud lucht ruimt rl116
# 3397                              mp koud lucht kamer
# 3402                                    ev koud lucht
# 3766                            drog viez lucht afnam
# 4094                                 zit lucht system
# 5162                    fancoilunit blaast warm lucht
# 5195                           storing lucht behandel
# 5347                           allen warm lucht airco
# 5815                     airco blaast koud lucht unit
# 5905         storing airco technisch ruimt warm lucht
# 5914           airco e timing ruimt blaast warm lucht
# 5942                     viez lucht gootsten aanrecht
# 6011            carrier verdiep blaast wer warm lucht
# 6043                carrier beid unit blaz koud lucht
# 6046                          av huis warm lucht unit
# 6054                  verwarm blaast allen koud lucht
# 6062        carrier blaast weinig koud lucht hog temp
# 6072                               ver lucht ingeblaz
# 6109                         kantor blaast koud lucht
# 6115        fancoilunit ruimt blaast allen koud lucht
# 6148                           vreemd rot lucht airco
# 6475                         koud lucht uitgeblaz lbk
# 6788                              ra koud lucht airco
# 6809                  jb blower blaz allen koud lucht
# 7358     ev ventilatie bov waterbed blaast koud lucht
# 7744                jb koud lucht rooster grot gymzal
# 7869                                    jh drog lucht
# 7951                           mp temp hog lucht drog
# 7869                                    jh drog lucht
# 8297                                jh lucht ververst
# 8302                   ra lucht radiator kamer teepan
# 8457                            erg drog lucht woning
# 8540                           mp temp hog drog lucht
# 9282                 mp drog lucht dagbestedingsruimt
# 9785                    airco lokal blaast lauw lucht
# 9887       ventillatiesystem blaast viez lucht woning
# 9992                afzuig blaast koud lucht grot zal
# 10060                     goed afzuig goed lucht binn
# 10518                    ijl lucht drog lucht benauwd
# 10625                                 last drog lucht
# 10999          airco expeditielokal blaast koud lucht
# 11822                                      koud lucht
# 12292              airco stuurruimt blaast koud lucht
# 13092            luchtbehandel aula blaast koud lucht
# 13155                        koel lucht binn receptie
# 14067                     muff lucht ventilatiesystem
# 15285          luchtbeh blas koud lucht radiator warm
# 15368                              vreemd lucht airco
# 15645                          afzuig zuigt val lucht
# 15768                      klacht klamm benauwd lucht
# 16024                 lbk controler blaast warm lucht
# Name: SO_Omschrijving, dtype: object

# %% [markdown]
# **____________________________________________________________**

# %% [markdown]
# Cooling

# %%
# Compute frequent itemsets using the Apriori algorithm.
frequent_itemsets_cooling = apriori(onehot_cooling, 
                            min_support =  0.00000001,
                            verbose = 1, 
                            use_colnames = True)


print(len(frequent_itemsets_cooling))

frequent_itemsets_cooling = frequent_itemsets_cooling[frequent_itemsets_cooling['itemsets'].apply(lambda x: len(x)) > 1]
frequent_itemsets_cooling = frequent_itemsets_cooling.sort_values(by=['support'], ascending=False).reset_index(drop=True)
frequent_itemsets_cooling.head(50)
# Out:
# Processing 1464 combinations | Sampling itemset size 8765
# 10809
#      support                       itemsets
# 0   0.169927               (storing, airco)
# 1   0.101467          (koelmachin, storing)
# 2   0.064792             (koeling, storing)
# 3   0.063570                (airco, lekkag)
# 4   0.040342                (defect, airco)
# 5   0.034230                  (airco, unit)
# 6   0.033007                 (ruimt, airco)
# 7   0.030562                  (lekt, airco)
# 8   0.028117                (airco, kantor)
# 9   0.026895           (airco, serverruimt)
# 10  0.026895                    (airco, iv)
# 11  0.022005                 (maakt, airco)
# 12  0.022005                    (ra, airco)
# 13  0.020782                    (airco, mp)
# 14  0.019560                  (doet, airco)
# 15  0.018337                  (ra, storing)
# 16  0.018337               (ruimt, storing)
# 17  0.017115                (stat, storing)
# 18  0.017115                (geluid, airco)
# 19  0.017115         (storing, serverruimt)
# 20  0.015892                 (airco, kamer)
# 21  0.015892              (woning, koeling)
# 22  0.014670        (ruimt, storing, airco)
# 23  0.014670                 (airco, koelt)
# 24  0.013447                 (lucht, airco)
# 25  0.013447               (lekkend, airco)
# 26  0.013447              (weinig, koeling)
# 27  0.013447                    (jb, airco)
# 28  0.012225         (geluid, airco, maakt)
# 29  0.012225                 (gkw, storing)
# 30  0.012225                    (airco, ev)
# 31  0.012225                  (storing, mp)
# 32  0.012225              (storing, kantor)
# 33  0.012225                (lucht, blaast)
# 34  0.012225                (geluid, maakt)
# 35  0.011002                (kantin, airco)
# 36  0.011002             (uitgevall, airco)
# 37  0.011002                  (storing, iv)
# 38  0.011002                 (lokal, airco)
# 39  0.011002  (storing, airco, serverruimt)
# 40  0.009780                  (jb, storing)
# 41  0.009780                  (stat, airco)
# 42  0.009780                     (hog, gkw)
# 43  0.009780                  (lucht, koud)
# 44  0.009780                    (jh, airco)
# 45  0.009780     (storing, koelinstallatie)
# 46  0.008557                      (gkw, os)
# 47  0.008557                   (lsr, airco)
# 48  0.008557                     (wko, gkw)
# 49  0.008557                (maakt, lawaai)

# %% [markdown]
# **Observe Itemsets____________________________________________________________**

# %%
word_list = list(frequent_itemsets_ventilation.iloc[33]['itemsets'])
indices = []
for transaction in df_so['SO_Omschrijving']:
    if all(contains_word_regex(transaction, word) for word in word_list):
        indices.append(df_so[df_so['SO_Omschrijving'] == transaction].index[0])

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(f"Original Dataset: {len(indices)} items\n{df_original.iloc[indices]['SO_Omschrijving']}")
    print(f"\nCleaned Dataset: {len(indices)} items\n{df_so.iloc[indices]['SO_Omschrijving']}")
# Out:
# Original Dataset: 14 items
# 2339                                    Storing warmtewiel
# 2848                            (JB) Warmtewiel staat stil
# 2848                            (JB) Warmtewiel staat stil
# 2856           storing frequentieregelaar warmtewiel bwd A
# 3785            Vervolgactie M&R Systemair-kast warmtewiel
# 3800                        Storing Warmtewiel LBK kantoor
# 5969                                Warmtewiel storing LBK
# 5969                                Warmtewiel storing LBK
# 6049                                warmtewiel draaid niet
# 6050                             LBK warmtewiel afgebroken
# 7073                     Storing warmtewiel en bevochtiger
# 7073                     Storing warmtewiel en bevochtiger
# 13673    GBS: Storing W installatie hoog urgent Warmtewiel
# 13681                               Storing warmtewiel LBK
# Name: SO_Omschrijving, dtype: object
#
# Cleaned Dataset: 14 items
# 2339                                  storing warmtewiel
# 2848                             jb warmtewiel stat stil
# 2848                             jb warmtewiel stat stil
# 2856          storing frequentieregelar warmtewiel bwd a
# 3785          vervolgactie m r systemair kast warmtewiel
# 3800                       storing warmtewiel lbk kantor
# 5969                              warmtewiel storing lbk
# 5969                              warmtewiel storing lbk
# 6049                                   warmtewiel draaid
# 6050                             lbk warmtewiel afgebrok
# 7073                      storing warmtewiel bevochtiger
# 7073                      storing warmtewiel bevochtiger
# 13673    gbs storing w installatie hog urgent warmtewiel
# 13681                             storing warmtewiel lbk
# Name: SO_Omschrijving, dtype: object

# %% [markdown]
# **____________________________________________________________**

# %%
# Compute all association rules for frequent_itemsets.
rules_cooling = association_rules(frequent_itemsets_cooling, 
                            metric = "lift", 
                         	min_threshold = 1)

print(len(rules_cooling))
rules_cooling
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kouro\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:181, in association_rules(df, metric, min_threshold, support_only)
#     180 try:
# --> 181     sA = frequent_items_dict[antecedent]
#     182     sC = frequent_items_dict[consequent]
#
# KeyError: frozenset({'storing'})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Compute all association rules for frequent_itemsets.
# ----> 2 rules_cooling = association_rules(frequent_itemsets_cooling,
#       3                             metric = "lift",
#       4                          	min_threshold = 1)
#       6 print(len(rules_cooling))
#       7 rules_cooling
#
# File c:\Users\kouro\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:192, in association_rules(df, metric, min_threshold, support_only)
#     183     except KeyError as e:
#     184         s = (
#     185             str(e) + "You are likely getting this error"
#     186             " because the DataFrame is missing "
#    (...)
#     190             " `support_only=True` option"
#     191         )
# --> 192         raise KeyError(s)
#     193     # check for the threshold
#     195 score = metric_dict[metric](sAC, sA, sC)
#
# KeyError: "frozenset({'storing'})You are likely getting this error because the DataFrame is missing  antecedent and/or consequent  information. You can try using the  `support_only=True` option"

# %% [markdown]
# Heating

# %%
# Compute frequent itemsets using the Apriori algorithm.
frequent_itemsets_heating = apriori(onehot_heating, 
                            min_support =  0.005,
                            max_len = 5, 
                            use_colnames = True)

# Print a preview of the frequent itemsets
print(len(frequent_itemsets_heating))
print(frequent_itemsets_heating)

# %%
# Compute all association rules for frequent_itemsets.
rules_heating = association_rules(frequent_itemsets_heating, 
                            metric = "lift", 
                         	min_threshold = 1)

print(len(rules_heating))
rules_heating

# %% [markdown]
# **Visualization**

# %% [markdown]
# Ventilation

# %%
rules_ventilation = association_rules(frequent_itemsets_ventilation, metric = 'support', min_threshold = 0.02)

# Replace frozen sets with strings.
rules_ventilation['antecedents'] = rules_ventilation['antecedents'].apply(lambda a: ','.join(list(a)))
rules_ventilation['consequents'] = rules_ventilation['consequents'].apply(lambda a: ','.join(list(a)))

# Transform data to matrix format and generate heatmap.
pivot = rules_ventilation.pivot(index='consequents', columns='antecedents', values='support')
sns.heatmap(pivot)

plt.title('Heatmap of Supports')
plt.yticks(rotation=0)
plt.show()

# %%
rules_ventilation = association_rules(frequent_itemsets_ventilation, metric = 'support', 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", data = rules_ventilation)
plt.show()

# %%
rules_ventilation = association_rules(frequent_itemsets_ventilation, metric = "support", 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules_ventilation)
plt.show()

# %%
# Compute the frequent itemsets.
frequent_itemsets_ventilation = apriori(onehot_ventilation, min_support = 0.02, 
                         use_colnames = True, max_len = 2)

# Compute rules from the frequent itemsets with the confidence metric.
rules_ventilation = association_rules(frequent_itemsets_ventilation, metric = 'support', 
                          min_threshold = 0.0)

# Convert rules into coordinates suitable for use in a parallel coordinates plot.
coords = rules_to_coordinates(rules_ventilation)

# Generate parallel coordinates plot
parallel_coordinates(coords, 'rule')
plt.legend([])
plt.show()

# %% [markdown]
# Cooling

# %%
rules_cooling = association_rules(frequent_itemsets_cooling, metric = 'support', min_threshold = 0.02)

# Replace frozen sets with strings.
rules_cooling['antecedents'] = rules_cooling['antecedents'].apply(lambda a: ','.join(list(a)))
rules_cooling['consequents'] = rules_cooling['consequents'].apply(lambda a: ','.join(list(a)))

# Transform data to matrix format and generate heatmap.
pivot = rules_cooling.pivot(index='consequents', columns='antecedents', values='support')
sns.heatmap(pivot)

plt.title('Heatmap of Supports')
plt.yticks(rotation=0)
plt.show()

# %%
rules_cooling = association_rules(frequent_itemsets_cooling, metric = 'support', 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", data = rules_cooling)
plt.show()

# %%
rules_cooling = association_rules(frequent_itemsets_cooling, metric = "support", 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules_cooling)
plt.show()

# %%
# Compute the frequent itemsets.
frequent_itemsets_cooling = apriori(onehot_cooling, min_support = 0.02, 
                         use_colnames = True, max_len = 2)

# Compute rules from the frequent itemsets with the confidence metric.
rules_cooling = association_rules(frequent_itemsets_cooling, metric = 'support', 
                          min_threshold = 0.0)

# Convert rules into coordinates suitable for use in a parallel coordinates plot.
coords = rules_to_coordinates(rules_cooling)

# Generate parallel coordinates plot
parallel_coordinates(coords, 'rule')
plt.legend([])
plt.show()

# %% [markdown]
# Heating

# %%
rules_heating = association_rules(frequent_itemsets_heating, metric = 'support', min_threshold = 0.02)

# Replace frozen sets with strings.
rules_heating['antecedents'] = rules_heating['antecedents'].apply(lambda a: ','.join(list(a)))
rules_heating['consequents'] = rules_heating['consequents'].apply(lambda a: ','.join(list(a)))

# Transform data to matrix format and generate heatmap.
pivot = rules_heating.pivot(index='consequents', columns='antecedents', values='support')
sns.heatmap(pivot)

plt.title('Heatmap of Supports')
plt.yticks(rotation=0)
plt.show()

# %%
rules_heating = association_rules(frequent_itemsets_heating, metric = 'support', 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", data = rules_heating)
plt.show()

# %%
rules_heating = association_rules(frequent_itemsets_heating, metric = "support", 
                          min_threshold = 0.0)

sns.scatterplot(x = "support", y = "confidence", 
                size = "lift", data = rules_heating)
plt.show()

# %%
# Compute the frequent itemsets.
frequent_itemsets_heating = apriori(onehot_heating, min_support = 0.02, 
                         use_colnames = True, max_len = 2)

# Compute rules from the frequent itemsets with the confidence metric.
rules_heating = association_rules(frequent_itemsets_heating, metric = 'support', 
                          min_threshold = 0.0)

# Convert rules into coordinates suitable for use in a parallel coordinates plot.
coords = rules_to_coordinates(rules_heating)

# Generate parallel coordinates plot
parallel_coordinates(coords, 'rule')
plt.legend([])
plt.show()
